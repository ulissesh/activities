# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/brunamulinari/BasicPythonProjects/main/Base_ficticia/baseficticia.csv', sep=';', na_values=['--', 'n/a', 'nada'])

# %%
df
# Out:
#       id              data_aq        produto  quantidade  valor UN      TotaL  \
# 0      0           01/01/2019         toalha           6  R$ 35,00  R$ 210,00
# 1      1           02/01/2019         toalha           6  R$ 35,00  R$ 210,00
# 2      2           03/01/2019         toalha           2  R$ 35,00   R$ 70,00
# 3      3           01/02/2019         toalha           5  R$ 35,00  R$ 175,00
# 4      4           02/02/2019         toalha           9  R$ 35,00  R$ 315,00
# ..   ...                  ...            ...         ...       ...        ...
# 544  544           31/07/2019  quebra_cabeca           9  R$ 19,99  R$ 179,91
# 545  545           01/08/2019  quebra_cabeca           3  R$ 19,99   R$ 59,97
# 546  546           30/07/2019  quebra_cabeca           4  R$ 19,99   R$ 79,96
# 547  547           31/07/2019  quebra_cabeca           1  R$ 19,99   R$ 19,99
# 548  548  2019-03-03 00:00:00  quebra_cabeca           8  R$ 19,99  R$ 159,92
#
#           setor
# ...

# %%
#para filtrar produto por coluna
df['produto'].unique()
# Out:
# array(['toalha', nan, 'roupao', 'saboneteSl', 'perfumeCH', 'hidratante',
#        'mouse', 'fone_ouvido', 'teclado', 'quebra_cabeca', 'domino',
#        'lego'], dtype=object)

# %%
df.head(4)
# Out:
#    id     data_aq produto  quantidade  valor UN      TotaL       setor
# 0   0  01/01/2019  toalha           6  R$ 35,00  R$ 210,00  Mesa_banho
# 1   1  02/01/2019  toalha           6  R$ 35,00  R$ 210,00         NaN
# 2   2  03/01/2019  toalha           2  R$ 35,00   R$ 70,00  mesa_banho
# 3   3  01/02/2019  toalha           5  R$ 35,00  R$ 175,00         NaN

# %%
df.tail(5)
# Out:
#       id              data_aq        produto  quantidade  valor UN      TotaL  \
# 544  544           31/07/2019  quebra_cabeca           9  R$ 19,99  R$ 179,91
# 545  545           01/08/2019  quebra_cabeca           3  R$ 19,99   R$ 59,97
# 546  546           30/07/2019  quebra_cabeca           4  R$ 19,99   R$ 79,96
# 547  547           31/07/2019  quebra_cabeca           1  R$ 19,99   R$ 19,99
# 548  548  2019-03-03 00:00:00  quebra_cabeca           8  R$ 19,99  R$ 159,92
#
#           setor
# 544  brinquedos
# 545  brinquedos
# 546  brinquedos
# 547  brinquedos
# 548  Brinquedos

# %%
df['produto'].value_counts()
# Out:
# domino           112
# toalha            83
# roupao            61
# mouse             60
# fone_ouvido       47
# perfumeCH         41
# teclado           41
# quebra_cabeca     35
# saboneteSl        32
# lego              23
# hidratante         7
# Name: produto, dtype: int64

# %%
import plotly.express as px

# %%
graphic1 = df['produto'].value_counts()

graphic1 = graphic1.reset_index()

fig = px.bar(graphic1, x= 'index', y='produto')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
graphic2 = df['setor'].value_counts()

graphic2 = graphic2.reset_index()
graphic2

fig = px.bar(graphic2, x= 'index', y='setor')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
graphic3 = df['produto'].value_counts(normalize=True)

graphic3 = graphic3.reset_index()
graphic3

fig = px.bar(graphic3, x= 'index', y='produto')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
def transforma_minuscula(x):
  return(str(x).lower())
df['setor']=df['setor'].apply(func = transforma_minuscula)

# %%
df
# Out:
#       id              data_aq        produto  quantidade  valor UN      TotaL  \
# 0      0           01/01/2019         toalha           6  R$ 35,00  R$ 210,00
# 1      1           02/01/2019         toalha           6  R$ 35,00  R$ 210,00
# 2      2           03/01/2019         toalha           2  R$ 35,00   R$ 70,00
# 3      3           01/02/2019         toalha           5  R$ 35,00  R$ 175,00
# 4      4           02/02/2019         toalha           9  R$ 35,00  R$ 315,00
# ..   ...                  ...            ...         ...       ...        ...
# 544  544           31/07/2019  quebra_cabeca           9  R$ 19,99  R$ 179,91
# 545  545           01/08/2019  quebra_cabeca           3  R$ 19,99   R$ 59,97
# 546  546           30/07/2019  quebra_cabeca           4  R$ 19,99   R$ 79,96
# 547  547           31/07/2019  quebra_cabeca           1  R$ 19,99   R$ 19,99
# 548  548  2019-03-03 00:00:00  quebra_cabeca           8  R$ 19,99  R$ 159,92
#
#           setor
# ...

# %%
df['TotaL'] = df['TotaL'].map(lambda x: str(x).replace('R$ ', ''))

# %%
df['valor UN'] = df['valor UN'].map(lambda x: str(x).replace(',', '.'))

# %%
df['valor UN'] = pd.to_numeric(df['valor UN'])
# Out:
# 26154.98

# %%
df['valor UN'].sum()
# Out:
# 26154.98

# %%
dataToalha= df[['data_aq', 'produto', 'quantidade']]

dataToalha = dataToalha.loc[dataToalha['produto']=='toalha',['data_aq', 'quantidade']]
dataToalha
# Out:
#         data_aq  quantidade
# 0    01/01/2019           6
# 1    02/01/2019           6
# 2    03/01/2019           2
# 3    01/02/2019           5
# 4    02/02/2019           9
# ..          ...         ...
# 142  27/12/2019           1
# 143  28/12/2019           8
# 144  29/12/2019           8
# 145  30/12/2019          11
# 146  31/12/2019           6
#
# [83 rows x 2 columns]

# %%
dataToalha = dataToalha.sort_values('data_aq')

figToalha = px.line(dataToalha, x= 'data_aq', y= 'quantidade')

figToalha.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
